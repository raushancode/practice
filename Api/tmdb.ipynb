# %%
import pandas as pd
import requests
import json

# %%
response = requests.get('https://api.themoviedb.org/3/movie/top_rated?api_key=8265bd1679663a7ea12ac168da84d2e8&language=en-US&page=1')

# %%
response.json()['results']
# Out:
# [{'adult': False,
#   'backdrop_path': '/tmU7GeKVybMWFButWEGl2M4GeiP.jpg',
#   'genre_ids': [18, 80],
#   'id': 238,
#   'original_language': 'en',
#   'original_title': 'The Godfather',
#   'overview': 'Spanning the years 1945 to 1955, a chronicle of the fictional Italian-American Corleone crime family. When organized crime family patriarch, Vito Corleone barely survives an attempt on his life, his youngest son, Michael steps in to take care of the would-be killers, launching a campaign of bloody revenge.',
#   'popularity': 100.525,
#   'poster_path': '/3bhkrj58Vtu7enYsRolD1fZdja1.jpg',
#   'release_date': '1972-03-14',
#   'title': 'The Godfather',
#   'video': False,
#   'vote_average': 8.7,
#   'vote_count': 17658},
#  {'adult': False,
#   'backdrop_path': '/wPU78OPN4BYEgWYdXyg0phMee64.jpg',
#   'genre_ids': [18, 80],
#   'id': 278,
#   'original_language': 'en',
#   'original_title': 'The Shawshank Redemption',
# ...

# %%
temp_df = pd.DataFrame(response.json()['results'])[['id', 'title', 'original_title', 'popularity', 'release_date', 'overview']]
temp_df.head(2)
# Out:
#     id                     title            original_title  popularity  \
# 0  238             The Godfather             The Godfather     100.525
# 1  278  The Shawshank Redemption  The Shawshank Redemption      74.053
#
#   release_date                                           overview
# 0   1972-03-14  Spanning the years 1945 to 1955, a chronicle o...
# 1   1994-09-23  Framed in the 1940s for the double murder of h...

# %%
base_url = "https://api.themoviedb.org/3/movie/top_rated?api_key=8265bd1679663a7ea12ac168da84d2e8&language=en-US&page={}"

# %%
df = pd.DataFrame()
for i in range(1,4):
    url = base_url.format(i)
    print(url)
    reponse = requests.get(url)
    temp2_df = pd.DataFrame(response.json()['results'])[['id', 'title', 'original_title', 'popularity', 'release_date', 'overview']]
    df = df.append(temp2_df,ignore_index=True)
df.head(22)
# Out:
# https://api.themoviedb.org/3/movie/top_rated?api_key=8265bd1679663a7ea12ac168da84d2e8&language=en-US&page=1
# https://api.themoviedb.org/3/movie/top_rated?api_key=8265bd1679663a7ea12ac168da84d2e8&language=en-US&page=2
# https://api.themoviedb.org/3/movie/top_rated?api_key=8265bd1679663a7ea12ac168da84d2e8&language=en-US&page=3
# C:\Users\Raushan\AppData\Local\Temp\ipykernel_13216\1182285986.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp2_df,ignore_index=True)
# C:\Users\Raushan\AppData\Local\Temp\ipykernel_13216\1182285986.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp2_df,ignore_index=True)
# ...
